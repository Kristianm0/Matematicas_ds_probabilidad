# %% [markdown]
# ##funciones compuestas

# %%
#importamos las librerias

import numpy as np
import matplotlib.pyplot as plt

#definimos las variables
n = 1000
x = np.linspace(-10, 10, num= n)

# creamos la funcion
def g(x):
  return x**2

def f(x):
  return np.sin(x)

y = g(x)

#aqui hago la composicion de la variable, cuando le digo que la variable de la funcion es la salida.
f_o_g =f(g(x))

plt.plot(f_o_g)
